# %% [markdown]
# # **Project 1 - Sales Analysis - ETL**

# %% [markdown]
# ## Objectives
#
# Extract data from provided CSV files, cleaning it apply feature engineering if necessary then save to
# a new CSV file
#
#
# ## Inputs
#
# CSV files provided:
#
# stores data-set.csv
# sales data-set.csv
# features data set.csv
#
# Renamed files to a uniform naming convention:
#
# Sales_Features_DataSet.csv
# Sales_DataSet.csv
# Sales_Stores_DataSet.csv
#
# Note: original files are stored in Data/OriginalFiles
#
#
# ## Outputs
#
# CSV file created from ETL etc:
#
# Sales_CleanedDataForInsights.csv
#
# ## Additional Comments

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
strCurrentDir = os.getcwd()
strCurrentDir

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(strCurrentDir))
print(f"Current Directory: \n {strCurrentDir}")

# %% [markdown]
# # Section 1 - Initalisation

# %% [markdown]
# ## Intitialise all variables to be used in global stack

# %%
fileSales_DataSet = None
fileSales_Features_DataSet = None
fileSales_Stores_DataSet = None

# %% [markdown]
# # Section 1 - Extraction

# %% [markdown]
# ## read csv files into variable for processing

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create your folder here
  # os.makedirs(name='')
except Exception as e:
  print(e)
